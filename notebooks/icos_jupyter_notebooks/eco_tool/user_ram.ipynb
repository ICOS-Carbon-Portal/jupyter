# %%
import pandas as pd 
keys ='CONTAINER ID   NAME   CPU %     MEM USAGE / LIMIT     MEM %     NET I/O    BLOCK I/O  PIDS'
keys = keys.replace(' / ','/')
keys = keys.replace(' %','_%')
keys = keys.replace(' ID','_ID')
keys = keys.replace('MEM U','MEM_U')
keys = keys.replace(' I/O','_I/O')
ls = [ x for x in keys.split(' ') if x!='']

# %%
val = '''05ba7fca1507   jupyter-kevin-moses           0.22%     280MiB / 100GiB       0.27%     452kB / 638kB     234MB / 0B        153
32bc9d857099   jupyter-zois                  0.16%     335MiB / 100GiB       0.33%     3.05MB / 1.08MB   256MB / 0B        168
595272f6400d   jupyter-ute                   0.11%     216.8MiB / 100GiB     0.21%     752kB / 8.33MB    239MB / 0B        137
c3b358e0b99b   jupyter-wouter                0.22%     1.35GiB / 100GiB      1.35%     81.2MB / 49.4MB   468MB / 0B        164
7f33bb3db74f   jupyter-zhendong              0.31%     793.5MiB / 100GiB     0.77%     142MB / 60.6MB    613MB / 6.66MB    453
cd4177ed38d3   jupyter-harry                 0.22%     187.3MiB / 100GiB     0.18%     10.4MB / 2.94MB   237MB / 0B        137
434ef3930ac0   jupyter-andre                 0.17%     182.8MiB / 100GiB     0.18%     10.5MB / 2.85MB   238MB / 0B        16
c5f8d91187ee   jupyter-remco                 0.22%     415.2MiB / 100GiB     0.41%     24.1MB / 71.3MB   416MB / 53.7MB    203
930234236c23   hub                           0.30%     94.95MiB / 279.4GiB   0.03%     86.3MB / 91.5MB   59.1MB / 0B       3
aefc249e8f06   jupyter-ingeborg              0.27%     634.3MiB / 279.4GiB   0.22%     118MB / 140MB     514MB / 495MB     297
2006e4e75714   jupyter-claudio               0.20%     294.2MiB / 279.4GiB   0.10%     13.1MB / 4.42MB   283MB / 0B        51
868554bf312e   jupyter-oleg-mirzov           0.26%     201.9MiB / 279.4GiB   0.07%     31.6MB / 17.6MB   482MB / 5.69MB    145
7cd759feb76f   jupyter-susana                0.09%     168.8MiB / 279.4GiB   0.06%     12.4MB / 153MB    232MB / 0B        136
9d269320c213   jupyter-steve                 0.54%     305.6MiB / 279.4GiB   0.11%     16.8MB / 19.9MB   427MB / 934kB     311
fa11a75023d2   jupyter-erik-koene            0.42%     2.095GiB / 279.4GiB   0.75%     1.09GB / 272MB    700MB / 112MB     1056
de8ad098b176   jupyter-gerrit                1.23%     46.7GiB / 279.4GiB    16.71%    550MB / 833MB     1.47GB / 56.8MB   1957
4d140bfa85d6   jupyter-alex                  1.44%     936.6MiB / 279.4GiB   0.33%     1.72GB / 1.42GB   869MB / 60.2MB    665
731e9f89aa34   jupyter-steinbacher           0.00%     234.6MiB / 279.4GiB   0.08%     24.4MB / 14.1MB   275MB / 22.4MB    155
77d6f48e9489   jupyter-janne-nurmela         0.45%     393.4MiB / 279.4GiB   0.14%     361MB / 102GB     35.7GB / 790MB    169
77a1ef024fe7   jupyter-daan-kivits           0.58%     2.842GiB / 279.4GiB   1.02%     218MB / 251MB     27.7GB / 145MB    1055
a092d599aba4   jupyter-xenia-uffrecht        0.97%     15.01GiB / 279.4GiB   5.37%     2.64GB / 2.25GB   30.7GB / 1.63GB   4742
9dcabcb70d6a   jupyter-samuel-chua           1.50%     2.614GiB / 279.4GiB   0.94%     209MB / 846MB     29.7GB / 428MB    3169
fe51a49d2f3a   jupyter-raakel-vuojolainen    2.48%     23.7GiB / 279.4GiB    8.48%     595MB / 9.73GB    47.5GB / 7.96GB   5272
be783bee8385   jupyter-nem-jgl1              0.72%     8.806GiB / 279.4GiB   3.15%     3.25GB / 3.92GB   17.7GB / 854MB    4860
86830f53b59f   jupyter-bart                  0.06%     430.8MiB / 279.4GiB   0.15%     171GB / 1.32GB    18GB / 731MB      170
c3e7094f4814   proxy                         0.20%     142.9MiB / 279.4GiB   0.05%     574GB / 574GB     16.5GB / 1.57MB   11'''

val = val.replace(' / ','/')
val = val.replace(' %','%')
rows_ls = [x for x in val.split('\n')]
cell_ls = [x for j in range(len(rows_ls)) for x in rows_ls[j].split(' ') if x!='']
cell_ls = [float(x[:-1]) if x[-1]=='%' else x  for x in cell_ls ]

# %%
data ={}

# len(ls) = 8...

for k in range(8):
    data[ls[k]] = [cell_ls[i] for i in range(len(cell_ls)) if i % 8 == k]
    
df = pd.DataFrame(data=data)
df.sort_values(by= 'MEM_%', ascending = False, inplace = True)


print(f"Total RAM:\t{df['MEM_%'].sum()}\nTotal CPU%:\t {df['CPU_%'].sum()}\n\n")
df
# Out:
# Total RAM:	84.03
# Total CPU%:	 125.66999999999999
#     CONTAINER_ID                        NAME   CPU_%    MEM_USAGE/LIMIT  \
# 15  de8ad098b176              jupyter-gerrit    1.23   46.7GiB/279.4GiB
# 49  b1011a721415              jupyter-ingrid    0.34   28.9GiB/279.4GiB
# 21  a7ac65a625b0                 jupyter-ida  100.64  26.06GiB/279.4GiB
# 61  fe51a49d2f3a  jupyter-raakel-vuojolainen    2.48   23.7GiB/279.4GiB
# 18  33cd82c85e3b        jupyter-sandro-meier    0.54   15.2GiB/279.4GiB
# ..           ...                         ...     ...                ...
# 27  1295128614ac      jupyter-rainer-hilland    0.00  174.2MiB/279.4GiB
# 43  935e8b67caf7              jupyter-moffat    0.00  167.8MiB/279.4GiB
# 41  77672259954c               jupyter-ville    0.00  166.9MiB/279.4GiB
# 64  c3e7094f4814                       proxy    0.20  142.9MiB/279.4GiB
# 8   930234236c23                         hub    0.30  94.95MiB/279.4GiB
#
#     MEM_%        NET_I/O      BLOCK_I/O  PIDS
# ...
