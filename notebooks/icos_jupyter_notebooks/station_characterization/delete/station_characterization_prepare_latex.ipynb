# %%
import os

# %%
all_stations=['GAT344', 'HPB131', 'HTM150', 'UTO', 'IPR100', 'JFJ', 'KIT200', 'KRE250', 'LIN099', 'LUT', 'CMN', 'NOR100', 'OPE120', 'OXK163', 'PAL', 'PUY', 'SMR125', 'SVB150', 'TOH147', 'TRN180','STE252']

#all_stations=['HTM150']
plotdir='output_tex_files'
if not os.path.exists(plotdir):
    os.mkdir(plotdir)
    
for station in all_stations:
    name_pdf=station+'_station_characterization.tex'
    
    with open(plotdir + '/' + name_pdf,"w") as file:
        
        file.write('\\documentclass[a4paper,8pt]{article}\n')
        
        file.write('\\usepackage{graphicx,caption}\n')

        file.write('\\usepackage[bottom=1in,top=1in, left=1in, right=1in]{geometry}\n')

        file.write('\\usepackage{subcaption}\n')

        file.write('\\graphicspath{{figures/}}\n') 

        file.write('\\usepackage{geometry}\n')

        file.write('\\pagenumbering{gobble}\n')

        file.write('\\usepackage{sidecap}\n')

        file.write('\\usepackage[export]{adjustbox}\n')

        file.write('\\usepackage[margin=1cm]{caption}\n')

        file.write('\\captionsetup[subfigure]{labelformat=empty}\n')

        file.write('\\usepackage{pdfpages}\n')

        file.write('\\begin{document}\n')

        file.write('\\newcommand\stationcode{' + station +'}\n')

        file.write('\\begin{flushleft}\n')
        file.write('\\begin{huge}\n')
        file.write('\\input{texts/\stationcode_text_1.txt}station characterization\n')
        file.write('\\end{huge}\n\n')

        file.write('\\begin{large}\n')
        file.write('\\bigskip\n')
        file.write('Based on footprints for 2018, an anthropogenic emissions database, a biogenic model and ancillary datalayers.\n')
        file.write('\\input{texts/\\stationcode_text_1.txt}is a class \\input{texts/\\stationcode_text_2.txt}\\unskip, tall tower, ICOS atmospheric measurement station located in \\input{texts/\\stationcode_text_4.txt}(latitue: \\input{texts/\\stationcode_text_5.txt}\\unskip, longitude: \\input{texts/\\stationcode_text_6.txt}\\unskip).\n')
        file.write('\\end{large}\n')
        file.write('\\end{flushleft}\n\n')
        
        file.write('\\begin{SCfigure}[][h]\n')
        file.write('\\includegraphics[width=0.6\\textwidth]{\\stationcode_figure_1}\n')
        file.write('\\captionsetup{labelformat=empty}\n')
        file.write('\\caption{\\begin{small}The \\textbf{sensitivity area map} shows the average footprint/sensitivity area for 2018. Relative sensitivity is used, but there are great differences in total average sensitivity between the different stations. \\protect\\input{texts/\\stationcode_text_1.txt}is in the \\protect\\input{texts/\\stationcode_text_7.txt}when it comes to total average sensitivity of the ICOS labeled atmospheric stations.\\end{small}\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip}\n')
        file.write('\end{SCfigure}\n\n')

        file.write('\\begin{figure}[!h]\n')
        file.write('\\begin{subfigure}[t]{0.5\\textwidth}\n')
        file.write('\\includegraphics[width=0.85\\linewidth]{\\stationcode_figure_2}\n')
        file.write('\\centering\n')
        file.write('\\captionsetup{width=.8\\linewidth}\n')
        file.write('\\caption{\\begin{small}The \\textbf{population sensitivity map} is the result of the average sensitivity map multiplied by the number of people living within each footprint cell. Relative to other labeled atmospheric stations, \\input{texts/\\stationcode_text_1.txt}is in the \\input{texts/\\stationcode_text_8.txt}when it comes to sensitivity to population.\\end{small}}\n')
        file.write('\\end{subfigure}%\n')
        file.write('\\begin{subfigure}[t]{0.5\\textwidth}\n')
        file.write('\\includegraphics[width=0.85\\linewidth]{\\stationcode_figure_3}\n')
        file.write('\\centering\n')
        file.write('\\captionsetup{width=.8\\linewidth}\n')
        file.write('\\caption{\\begin{small}The \\textbf{point source contribution map} is the result of the average sensitivity map multiplied by the {\\ensuremath{\\mathrm{CO_2}}} emissions within each footprint cell which in turn have been translated into expected influence of the {\\ensuremath{\\mathrm{CO_2}}} concentration at the station. \\input{texts/\\stationcode_text_1.txt}is a station with relatively \\input{texts/\\stationcode_text_9.txt}influence of point source emissions, placing in the \\input{texts/\\stationcode_text_10.txt}of the atmospheric stations.\\end{small}}\n')
        file.write('\\end{subfigure}\n')
        file.write('\\end{figure}\n\n')

        file.write('\\pagebreak\n\n')

        file.write('\\begin{figure}[!ht]\n')
        file.write('\\includegraphics[width=0.9\\textwidth]{\\stationcode_figure_4}\n')
        file.write('\\raisebox{4.5cm}[0pt][0pt]{%\n')
        file.write('\\hspace{7.5cm}%\n')
        file.write('\\captionsetup{labelformat=empty}\n')
        file.write('\\parbox{9.2cm}{\\caption{\\begin{small}The \\textbf{land cover wind rose}  is similar to the maps in that the center represents the station and the distribution of the land cover around the center indicate the direction of the different land cover classes in relation to the station.\\end{small}}}}\n')
        file.write('\\end{figure}\n\n')

        file.write('\\begin{SCfigure}[][h]\n')
        file.write('\\includegraphics[width=0.6\\textwidth]{\\stationcode_figure_5}\n')
        file.write('\\captionsetup{labelformat=empty}\n')
        file.write('\\caption{\\begin{small}In the \\textbf{multiple variables graph} the total of all values used to generate the maps are shown relative to the other atmospheric stations. The remaining three variables – GEE, respiration and anthropogenic contribution – are the averages for 2018. \\protect\\input{texts/\\stationcode_text_1.txt}\\unskip’s placement on the y-axis is determined relative to the minimum and maximum values given all stations.\\newline\\newline\n')
        file.write('The 2018 absolute averages are used in the multiple variables graph is found in the \\textbf{seasonal variations table}. The values for the different seasons have been computed relative to these.\\end{small}\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip}\n')
        file.write('\\end{SCfigure}\n\n')

        file.write('\\begin{figure}[!h]\n')
        file.write('\\centering\n')
        file.write('\\includegraphics[width=1\\textwidth]{\\stationcode_figure_6}\n')
        file.write('\\end{figure}\n\n')

        file.write('%\\includepdf[pages=-,pagecommand={},width=1.2\\textwidth]{texts/Specifications.pdf}\n')

        #specifications without top and bottom. save as text file
        file.write('\\end{document}\n')

# %%
#How to download a whole folder in python.
#next, can use the command line to extract the figures. Ex for me (cannot use "Ida Strömberg in path"):
#can do the same for the figures and texts

#tar -xvzf C:\station_char\archive.tar.gz -C C:\station_char\station_characterization_latex

# %%
# %%bash
# tar -czf output_test_files.tar.gz output_tex_files

# %% [markdown]
# ## UPDATE 2021-01-28
#
# Move this file to the upd_station_characterization folder...
#
# Read setting json instead of input text files.
#
# Make as function when running the station characterization notebook --> not in a loop at that point.
#
# Result should be a file in the same folder where all the information is going.
#
# Maybe also need the specifications in the folder? Probably not in the folder - but rather on a higher level.
# That way don't have to put one specifications file in each folder.
#
# Run locally to make sure that it works --> download the json file rather than the individual text files (ex one for lat perviously)..

# %%
all_stations=['GAT344', 'HPB131', 'HTM150', 'UTO', 'IPR100', 'JFJ', 'KIT200', 'KRE250', 'LIN099', 'LUT', 'CMN', 'NOR100', 'OPE120', 'OXK163', 'PAL', 'PUY', 'SMR125', 'SVB150', 'TOH147', 'TRN180','STE252']

#all_stations=['HTM150']
plotdir='output_tex_files'
if not os.path.exists(plotdir):
    os.mkdir(plotdir)
    
for station in all_stations:
    name_pdf=station+'_station_characterization.tex'
    
    with open(plotdir + '/' + name_pdf,"w") as file:
        
        file.write('\\documentclass[a4paper,8pt]{article}\n')
        
        file.write('\\usepackage{graphicx,caption}\n')

        file.write('\\usepackage[bottom=1in,top=1in, left=1in, right=1in]{geometry}\n')

        file.write('\\usepackage{subcaption}\n')

        file.write('\\graphicspath{{figures/}}\n') 

        file.write('\\usepackage{geometry}\n')

        file.write('\\pagenumbering{gobble}\n')

        file.write('\\usepackage{sidecap}\n')

        file.write('\\usepackage[export]{adjustbox}\n')

        file.write('\\usepackage[margin=1cm]{caption}\n')

        file.write('\\captionsetup[subfigure]{labelformat=empty}\n')

        file.write('\\usepackage{pdfpages}\n')

        file.write('\\begin{document}\n')

        file.write('\\newcommand\stationcode{' + station +'}\n')

        file.write('\\begin{flushleft}\n')
        file.write('\\begin{huge}\n')
        file.write('\\input{texts/\stationcode_text_1.txt}station characterization\n')
        file.write('\\end{huge}\n\n')

        file.write('\\begin{large}\n')
        file.write('\\bigskip\n')
        file.write('Based on footprints for 2018, an anthropogenic emissions database, a biogenic model and ancillary datalayers.\n')
        file.write('\\input{texts/\\stationcode_text_1.txt}is a class \\input{texts/\\stationcode_text_2.txt}\\unskip, tall tower, ICOS atmospheric measurement station located in \\input{texts/\\stationcode_text_4.txt}(latitue: \\input{texts/\\stationcode_text_5.txt}\\unskip, longitude: \\input{texts/\\stationcode_text_6.txt}\\unskip).\n')
        file.write('\\end{large}\n')
        file.write('\\end{flushleft}\n\n')
        
        file.write('\\begin{SCfigure}[][h]\n')
        file.write('\\includegraphics[width=0.6\\textwidth]{\\stationcode_figure_1}\n')
        file.write('\\captionsetup{labelformat=empty}\n')
        file.write('\\caption{\\begin{small}The \\textbf{sensitivity area map} shows the average footprint/sensitivity area for 2018. Relative sensitivity is used, but there are great differences in total average sensitivity between the different stations. \\protect\\input{texts/\\stationcode_text_1.txt}is in the \\protect\\input{texts/\\stationcode_text_7.txt}when it comes to total average sensitivity of the ICOS labeled atmospheric stations.\\end{small}\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip}\n')
        file.write('\end{SCfigure}\n\n')

        file.write('\\begin{figure}[!h]\n')
        file.write('\\begin{subfigure}[t]{0.5\\textwidth}\n')
        file.write('\\includegraphics[width=0.85\\linewidth]{\\stationcode_figure_2}\n')
        file.write('\\centering\n')
        file.write('\\captionsetup{width=.8\\linewidth}\n')
        file.write('\\caption{\\begin{small}The \\textbf{population sensitivity map} is the result of the average sensitivity map multiplied by the number of people living within each footprint cell. Relative to other labeled atmospheric stations, \\input{texts/\\stationcode_text_1.txt}is in the \\input{texts/\\stationcode_text_8.txt}when it comes to sensitivity to population.\\end{small}}\n')
        file.write('\\end{subfigure}%\n')
        file.write('\\begin{subfigure}[t]{0.5\\textwidth}\n')
        file.write('\\includegraphics[width=0.85\\linewidth]{\\stationcode_figure_3}\n')
        file.write('\\centering\n')
        file.write('\\captionsetup{width=.8\\linewidth}\n')
        file.write('\\caption{\\begin{small}The \\textbf{point source contribution map} is the result of the average sensitivity map multiplied by the {\\ensuremath{\\mathrm{CO_2}}} emissions within each footprint cell which in turn have been translated into expected influence of the {\\ensuremath{\\mathrm{CO_2}}} concentration at the station. \\input{texts/\\stationcode_text_1.txt}is a station with relatively \\input{texts/\\stationcode_text_9.txt}influence of point source emissions, placing in the \\input{texts/\\stationcode_text_10.txt}of the atmospheric stations.\\end{small}}\n')
        file.write('\\end{subfigure}\n')
        file.write('\\end{figure}\n\n')

        file.write('\\pagebreak\n\n')

        file.write('\\begin{figure}[!ht]\n')
        file.write('\\includegraphics[width=0.9\\textwidth]{\\stationcode_figure_4}\n')
        file.write('\\raisebox{4.5cm}[0pt][0pt]{%\n')
        file.write('\\hspace{7.5cm}%\n')
        file.write('\\captionsetup{labelformat=empty}\n')
        file.write('\\parbox{9.2cm}{\\caption{\\begin{small}The \\textbf{land cover wind rose}  is similar to the maps in that the center represents the station and the distribution of the land cover around the center indicate the direction of the different land cover classes in relation to the station.\\end{small}}}}\n')
        file.write('\\end{figure}\n\n')

        file.write('\\begin{SCfigure}[][h]\n')
        file.write('\\includegraphics[width=0.6\\textwidth]{\\stationcode_figure_5}\n')
        file.write('\\captionsetup{labelformat=empty}\n')
        file.write('\\caption{\\begin{small}In the \\textbf{multiple variables graph} the total of all values used to generate the maps are shown relative to the other atmospheric stations. The remaining three variables – GEE, respiration and anthropogenic contribution – are the averages for 2018. \\protect\\input{texts/\\stationcode_text_1.txt}\\unskip’s placement on the y-axis is determined relative to the minimum and maximum values given all stations.\\newline\\newline\n')
        file.write('The 2018 absolute averages are used in the multiple variables graph is found in the \\textbf{seasonal variations table}. The values for the different seasons have been computed relative to these.\\end{small}\\bigskip\\bigskip\\bigskip\\bigskip\\bigskip}\n')
        file.write('\\end{SCfigure}\n\n')

        file.write('\\begin{figure}[!h]\n')
        file.write('\\centering\n')
        file.write('\\includegraphics[width=1\\textwidth]{\\stationcode_figure_6}\n')
        file.write('\\end{figure}\n\n')

        file.write('%\\includepdf[pages=-,pagecommand={},width=1.2\\textwidth]{texts/Specifications.pdf}\n')

        #specifications without top and bottom. save as text file
        file.write('\\end{document}\n')
